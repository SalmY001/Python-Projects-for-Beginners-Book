# %%
# Code examples taken from book 'Python Projects for Beginners', Connor P.Miliken, 2020, www.apress.com

# %%
"""
This is a multi-line comment
"""

print("Hello")  # This is also a comment
# Out:
# Hello

# %% [markdown]
# ### Integers and Floats

# %%
print(2)
print(10)
# Out:
# 2
# 10

# %%
print(10.3952)
print(8.0)
# Out:
# 10.3952
# 8.0

# %% [markdown]
# ### Booleans

# %%
print(True)
print(False)
# Out:
# True
# False

# %% [markdown]
# ### Strings

# %%
# the following are strings
print("")
print("There is a snake in my boot!")
print("True")
# Out:
# There is a snake in my boot!
# True

# %%
print("Hello, I am Geena")
# Out:
# Hello, I am Geena

# %%
type(9) # checking the type of a value
# Out:
# int

# %% [markdown]
# ### Variables

# %%
num1 =5 
num2 = 8.4
print(num1, num2)
# Out:
# 5 8.4

# %%
switch = True   # storing a boolean into a variable
print(switch)
# Out:
# True

# %%
name = 'John Smith'   # storing strings into a variable
fav_number = '9'
print(name, fav_number)
# Out:
# John Smith 9

# %%
result = num1 + num2 # using two variables to create another variable
print(result)
# Out:
# 13.4

# %%
result +=1  # each time you execute the statement it increases by 1
print(result)
# Out:
# 16.4

# %%
result *=num1
print(result)
# Out:
# 82.0

# %%
# redeclaring a variable
name = 'John'
print(name)
# Out:
# John

# %%
name = 'Sam'
print(name)
# Out:
# Sam

# %%
x = 3
y = 10
result = x * y
print(result)
# Out:
# 30

# %%
width = 245.54
height = 13.66
area = width * height
print(area)
# Out:
# 3354.0764

# %% [markdown]
# ### Working with strings

# %%
name = "John"+" "+"Smith"
print(name)
# Out:
# John Smith

# %%
first_name="John"
last_name="Smith"
full_name=first_name+" "+last_name
print(full_name)
# Out:
# John Smith

# %%
name = "John"   #.format strings
print( "Hello{}".format(name) )
print("Hello {}".format(name))
print("Hello {}, you are {} years old!".format(name,28))
# Out:
# HelloJohn
# Hello John
# Hello John, you are 28 years old!

# %%
age = int(input())
print("Your age is:",age)
# Out:
#  25
# Your age is: 25

# %%
print("Hello {}, you are {} years old!".format(name,age))
# Out:
# Hello John, you are 25 years old!

# %%
name = "John"
print(f"Hello {name}")  # using the f string you are able to inject a variable into a string
# Out:
# Hello John

# %% [markdown]
# ### Formatting in Python 2 (Older version of Python)

# %%
first_name="John"
last_name="Smith"
print("Hello, %s %s" % (first_name, last_name))
# Out:
# Hello, John Smith

# %% [markdown]
# ### String Index

# %%
word= "Hello"
print(word[0])  # first letter in the string, reading left to right
print(word[-1])  # last letter in the string, reading right to left
print(word[4])
print(word[1])
print(word[-5])  # first letter in the string, reading right to left
# Out:
# H
# o
# o
# e
# H

# %% [markdown]
# ### String slicing

# %%
print(word[0:2])  # This will give first two letters of the string - 0=start point, 2=stopping point
# Out:
# He

# %%
print(word[0:5:2]) # increment by 2
# Out:
# Hlo

# %%
int = 29    # variable inject exercise
float = 3.05
boolean = True
name = "Katie"
print(int,float,boolean,name)
# Out:
# 29 3.05 True Katie

# %%
name = "Yvonne"
sport = "athletics"
coding = "Python"
print(f"{name}'s favourite sport is {sport}.")
print(f"{name}'s working on {coding} programming!")
# Out:
# Yvonne's favourite sport is athletics.
# Yvonne's working on Python programming!

# %%
name = "john smith" # This puts the name to start with capital letters
print(name.title())
# Out:
# John Smith

# %%
print(name.lower()) # name in lower case
# Out:
# john smith

# %%
# replacing an exclamation point with a period
words = "Hello there!"
print(words.replace( "!", "."))
# Out:
# Hello there.

# %%
print(words)
# Out:
# Hello there!

# %%
# re-declare the variable
words = words.replace('!','.')

# %%
print(words)
# Out:
# Hello there.

# %%
s= "Look over that way"  # This is searching for the word "over" in the string, bringing back the index of the first letter of "over"
print(s.find("over"))
# Out:
# 5

# %%
# strip whitespace from beginning or end of the string
name = "     John     "
print( name.strip())
# Out:
# John

# %%
name1 = "John"
print(name.strip())
# Out:
# John

# %%
print(name.lstrip())  #Left Strip, whitespace removed from the left only
print(name.rstrip())  #Right Strip, whitespace removed from the right only
# Out:
# John
#      John

# %%
# converting a string into a list of words
s1 = "These words are separated by spaces"
print( s1.split(" "))
# Out:
# ['These', 'words', 'are', 'separated', 'by', 'spaces']

# %% [markdown]
# ### Converting strings into uppercase or lower case

# %%
string = "upper"
string.upper()
# Out:
# 'UPPER'

# %%
s1.upper()
# Out:
# 'THESE WORDS ARE SEPARATED BY SPACES'

# %%
string2 = "LOWER"
string2.lower()
# Out:
# 'lower'

# %%
help(" ".upper)
# Out:
# Help on built-in function upper:
#
# upper() method of builtins.str instance
#     Return a copy of the string converted to uppercase.

# %% [markdown]
# ### Project printing receipts

# %%
# Create a product and price for three items
p1_name, p1_price = "Books", 49.95
p2_name, p2_price = "Computer", 579.99
p3_name, p3_price = "Monitor", 124.89

# create a company name and informnation
company_name = "coding temple, inc"
company_address = "283 Franklin St."
company_city = "Boston, MA"

# declare ending message
message = "Thanks for shopping with us today!"

# create a top border
print("*"*50)

# print company info first, using format
print("\t\t{}".format(company_name.title()))
print("\t\t{}".format(company_address.title()))
print("\t\t{}".format(company_city.title()))

# print each product undedr the heading
print("\tProduct Name\tProduct Price")   
print("\t{}\t\t${}".format(p1_name.title(), p1_price))
print("\t{}\t${}".format(p2_name.title(), p2_price))
print("\t{}\t\t${}".format(p3_name.title(), p3_price))

print("="*50)   # print a line between sections

print("\t\t\tTotal")  # Total section
total = p1_price + p2_price + p3_price  # calculate total price and print it
print("\t\t\t${}".format(total))
print("="*50)

# output thank you message
print("\n\t{}\n".format(message))
print("*"*50)
# Out:
# **************************************************
# 		Coding Temple, Inc
# 		283 Franklin St.
# 		Boston, Ma
# 	Product Name	Product Price
# 	Books		$49.95
# 	Computer	$579.99
# 	Monitor		$124.89
# ...
# 			Total
# 			$754.83
# ...
#
# 	Thanks for shopping with us today!
#
# **************************************************
